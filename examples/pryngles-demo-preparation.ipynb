# %%
# %load_ext autoreload
# %autoreload 2
import pryngles as pr
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
pr.version
# Out:
# '0.7.3.1'

# %%
sys=pr.System()

# %%
S=sys.add("Star")

# %%
P=sys.add("Planet",primary=S,nspangles=200,radius=0.3,x=3)

# %%
R=sys.add("Ring",primary=P,fi=2,fe=3,i=40*pr.Consts.deg,roll=0*pr.Consts.deg)

# %%
M=sys.add("Planet",bhash="Moon",primary=P,x=1.5,radius=0.1)

# %%
RM=sys.add("Ring",primary=M,fi=2,fe=3,i=30*pr.Consts.deg,roll=60*pr.Consts.deg)

# %%
sys.spangle_system()

# %%
sys.set_observer(nvec=[1,1,1])
sys.set_luz(nvec=[0,0,1])

# %%
sys.sg.plot3d()
# Out:
# <img src="data:image/png;base64,..." width="500">

# %%
sys.sg._interact_plot2d()
# Out:
# interactive(children=(FloatSlider(value=70.0, continuous_update=False, description='lon_luz', max=360.0, reado…

# %%
sys.sg._interact_intersect()
# Out:
# interactive(children=(FloatSlider(value=0.0, continuous_update=False, description='lon', max=360.0, readout_fo…

# %%
sys.sg._animate_intersect()
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %% [markdown]
# --End--

# %%
sys=pr.System()
S=sys.add("Star")
P=sys.add("Planet",primary=S,nspangles=200,radius=0.3,a=3)
R=sys.add("Ring",primary=P,fi=2,fe=3,i=40*pr.Consts.deg,roll=0*pr.Consts.deg)
M=sys.add("Planet",bhash="Moon",primary=P,a=1.5,M=180*pr.Consts.deg,radius=0.1)
RM=sys.add("Ring",primary=M,fi=2,fe=3,i=30*pr.Consts.deg,roll=60*pr.Consts.deg)
sys.spangle_system()
sys.sg.set_observer(nvec=[1,1,1])
sys.sg.set_luz(nvec=[0,0,1])
sys.sg._view_intersect(lon=218,lat=22)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
sys.sg._view_intersect(lon=52,lat=0)
# Out:
# <img src="data:image/png;base64,..." width="639.9999861283738">

# %%
cond=sys.sg.set_intersect(nvec=[1,0,0])

# %%
# %timeit cond=sys.sg.set_intersect(nvec=[1,0,0])
# Out:
# 90.5 ms ± 846 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
