# %% [markdown]
# ## Pryngles Tutorial: Evolution

# %% [markdown]
# In this tutorial we introduce the basic elements of the newest version of Pryngles (>=1.0.x).

# %%
from pryngles import *
from IPython.display import Image
from celluloid import Camera 
version
# Out:
# '0.7.3.1'

# %% [markdown]
# ## A simple system

# %% [markdown]
# The most simple system:

# %%
sys=System()
S=sys.add()
P=sys.add("Planet",primary=S,radius=0.1,x=3)
sys.spangle_system()
sys.sg.plot2d();
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# Focus on planet:

# %%
sys=System()
S=sys.add()
P=sys.add("Planet",primary=S,radius=0.1,x=3)
sys.spangle_system()
sys.sg.plot2d(include=["Planet"]);
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# Add information to plot:

# %%
sys=System()
S=sys.add()
P=sys.add("Planet",primary=S,radius=0.1,x=3)
sys.spangle_system()
sys.sg.plot2d(include=["Planet"],show_azim=True);
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# DataFrame with key information:

# %%
sys.data[SPANGLER_KEY_ORDERING]
# Out:
#        bhash  spangle_type     x_ecl     y_ecl   z_ecl  \
# 0       Star             6 -0.043426 -0.010637 -0.9990
# 1       Star             6  0.067874 -0.037204 -0.9970
# 2       Star             6 -0.032152  0.094558 -0.9950
# 3       Star             6 -0.047501 -0.108142 -0.9930
# 4       Star             6  0.122483  0.054008 -0.9910
# ...      ...           ...       ...       ...     ...
# 1969  Planet             0  2.990739 -0.009666  0.0991
# 1970  Planet             0  3.011786  0.000769  0.0993
# 1971  Planet             0  2.992212  0.006253  0.0995
# 1972  Planet             0  3.001177 -0.007650  0.0997
# 1973  Planet             0  3.002484  0.003718  0.0999
#
#                                                  ns_ecl  azim_obs      n_obs  \
# 0     [-0.04342638520937469, -0.010637155054194778, ...  3.141593  [0, 0, 1]
# 1     [0.06787377443992139, -0.03720417642252864, -0...  3.141593  [0, 0, 1]
# ...

# %% [markdown]
# ## Exoring in the new Pryngles

# %% [markdown]
# Add a ring:

# %%
sys=System()
S=sys.add()
P=sys.add("Planet",primary=S,radius=0.1,x=3)
R=sys.add("Ring",primary=P,
          fi=1.3,fe=2.3,
          i=-20*Consts.deg,roll=0*Consts.deg)
sys.spangle_system()
sys.update_perspective(n_obs=Science.direction(120,0))
sys.sg.plot2d(include=["Planet","Ring"],show_azim=False);
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# Special variable with transit conditions:

# %%
cond=(sys.data.transit_over_obs!="")
sys.data.loc[cond,["transit_over_obs"]]
# Out:
#                   transit_over_obs
# 1406    Ring:-1.726e+00:4.348e-01&
# 1419    Ring:-1.726e+00:4.240e-01&
# 1432    Ring:-1.726e+00:3.937e-01&
# 1440    Ring:-1.726e+00:4.330e-01&
# 1453    Ring:-1.726e+00:4.145e-01&
# ...                            ...
# 2969  Planet:-1.600e+00:3.936e-01&
# 2977  Planet:-1.600e+00:8.580e-01&
# 2982  Planet:-1.600e+00:6.377e-01&
# 2990  Planet:-1.600e+00:4.867e-01&
# 3003  Planet:-1.600e+00:4.425e-01&
#
# [232 rows x 1 columns]

# %% [markdown]
# Highlights points in planet seing through rings:

# %%
cond=(sys.data.transit_over_obs.apply(lambda x:'Planet' in x))
sys.sg.plot2d(include=["Planet","Ring"],highlight=(cond,dict()))
# Out:
# <img src="data:image/png;base64,..." width="500">
# (-2.598076292235615, -0.00021995947315096279)

# %%
cond=(sys.data.hidden_by_obs.apply(lambda x:'Ring' in x))
sys.sg.plot2d(include=["Planet","Ring"],highlight=(cond,dict()))
# Out:
# <img src="data:image/png;base64,..." width="500">
# (-2.598076292235615, -0.00021995947315096279)

# %%
print_df(sys.data.head())
# Out:
# <table border="1" class="dataframe">
#   <thead>
#     <tr style="text-align: right;">
#       <th></th>
#       <th>bhash</th>
#       <th>spangle_type</th>
#       <th>geometry</th>
#       <th>scale</th>
#       <th>n_equ</th>
#       <th>alpha_equ</th>
#       <th>w</th>
#       <th>q0</th>
#       <th>center_equ</th>
#       <th>x_equ</th>
#       <th>y_equ</th>
#       <th>z_equ</th>
#       <th>r_equ</th>
#       <th>q_equ</th>
#       <th>f_equ</th>
#       <th>ns_equ</th>
#       <th>center_ecl</th>
#       <th>x_ecl</th>
#       <th>y_ecl</th>
#       <th>z_ecl</th>
#       <th>wx_ecl</th>
#       <th>wy_ecl</th>
#       <th>ns_ecl</th>
#       <th>center_int</th>
#       <th>x_int</th>
#       <th>y_int</th>
#       <th>z_int</th>
#       <th>ns_int</th>
#       <th>rho_int</th>
#       <th>az_int</th>
#       <th>cosf_int</th>
#       <th>cos_int</th>
#       <th>azim_int</th>
#       <th>n_int</th>
#       <th>n_int_ecl</th>
#       <th>d_int</th>
# ...

# %%
sys.save_to("system.bin")

# %% [markdown]
# Highlight points in partial shadow:

# %%
cond=(sys.data.hidden_by_luz.apply(lambda x:'Ring' in x))&\
     (sys.data.visible)
sys.sg.plot2d(include=["Planet","Ring"],highlight=(cond,dict()));
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# ## Exomoons in the new Pryngles

# %% [markdown]
# System with an exomoon:

# %%
sys=System()

S=sys.add()
P=sys.add("Planet",primary=S,radius=0.1,x=3)
R=sys.add("Ring",primary=P,
          fi=1.3,fe=2.3,
          i=-20*Consts.deg,roll=0*Consts.deg)

M=sys.add("Planet",bhash="Moon",primary=P,radius=0.02,x=2.5,z=0.05)

sys.spangle_system()
sys.update_perspective(n_obs=Science.direction(120,0))
sys.sg.plot2d(include=["Planet","Moon","Ring"],show_azim=False)
# Out:
# <img src="data:image/png;base64,..." width="500">
# (-2.598076292235615, -0.00021995947315096279)

# %% [markdown]
# Check orbit:

# %%
Plot.animate_rebound(sys.sim,filename="figures/system-animate.gif")
Image(open("figures/system-animate.gif","rb").read())
# Out:
# <img src="data:image/png;base64,..." width="640">
# 100%|██████████| 100/100 [00:00<00:00, 267.32it/s]

# %% [markdown]
# Create an orbit for a hierarchical N-body system:

# %%
units=['au','msun','yr']
orbit=Orbit(m1=1,
            m2=Orbit(m1=1e-3,
                     m2=1e-6,
                     units=units,
                     a=0.5,inc=30*Consts.deg,M=180*Consts.deg),
            units=units,
            a=20,e=0)
orbit.calculate_orbit()
Plot.animate_rebound(orbit.sim,filename="figures/system-moon-animation.gif")
Image(open("figures/system-moon-animation.gif","rb").read())
# Out:
# <img src="data:image/png;base64,..." width="640">
# 100%|██████████| 100/100 [00:00<00:00, 821.29it/s]

# %% [markdown]
# Use that orbit for creating Planetary System:

# %%
units=['au','msun','yr']
orbit=Orbit(m1=1,
            m2=Orbit(m1=1e-3,
                     m2=1e-6,
                     units=units,
                     a=0.5,inc=30*Consts.deg,M=180*Consts.deg),
            units=units,
            a=20,e=0)
orbit.calculate_orbit()
sim,states=orbit.get_states()

sys=System(units=units)

S=sys.add(**states[0])
P=sys.add("Planet",primary=S,radius=0.1,**states[1])
R=sys.add("Ring",primary=P,
          fi=1.3,fe=2.3,
          i=-20*Consts.deg,roll=0*Consts.deg)

M=sys.add("Planet",bhash="Moon",primary=P,radius=0.02,**states[2])

sys.spangle_system()
sys.update_perspective(n_obs=Science.direction(120,0))
sys.sg.plot2d(include=["Planet","Moon","Ring"],show_azim=False)
# Out:
# <img src="data:image/png;base64,..." width="500">
# (-17.303620245920364, -0.00021995947315096279)

# %% [markdown]
# Integrate the system:

# %%
sys.integrate(6)
sys.update_perspective()
sys.sg.plot2d(include=["Planet","Moon","Ring"]);
# Out:
# <img src="data:image/png;base64,..." width="500">

# %% [markdown]
# Animate the visualization:

# %%
from tqdm import tqdm
for i,t in enumerate(tqdm(np.linspace(0,20,50))):
    sys.integrate(t)
    sys.update_perspective()
    if i==0:
        del sys.sg.fig2d
    sys.sg.plot2d(include=["Planet","Moon","Ring"],newfig=False)
    if i==0:
        camera=Camera(sys.sg.fig2d)
    else:
        camera.snap()
# Out:
#   0%|          | 0/50 [00:00<?, ?it/s]
# <img src="data:image/png;base64,..." width="500">
# 100%|██████████| 50/50 [01:13<00:00,  1.46s/it]

# %% [markdown]
# Save animation:

# %%
anim=camera.animate(interval=200,repeat=True,blit=False)
anim.save("figures/planet-moon-animation.gif")
Image(open("figures/planet-moon-animation.gif","rb").read())

# %% [markdown]
# ## Multiring system

# %%
sys=System()
S=sys.add()
P=sys.add("Planet",primary=S,radius=0.1,x=3)
R1=sys.add("Ring",bhash="Ring1",primary=P,
          fi=1.3,fe=2.3,
          i=-20*Consts.deg,roll=0*Consts.deg)
R2=sys.add("Ring",bhash="Ring2",primary=P,
          fi=2.5,fe=3.5,
          i=90*Consts.deg,roll=110*Consts.deg)

sys.spangle_system()
sys.update_perspective(n_obs=Science.direction(120,0))
sys.sg.plot2d(include=["Planet","Ring1","Ring2"],show_azim=False);
# Out:
# <img src="data:image/png;base64,..." width="499.9999891627921">

# %% [markdown]
# Done!
